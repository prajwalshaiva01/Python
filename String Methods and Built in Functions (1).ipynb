# %% [markdown]
# 1. Convert a string to uppercase
#
#         Input: "data science"
#        Output: "DATA SCIENCE"

# %%
text = " data science "
print(text.upper())
# Out:
#  DATA SCIENCE

# %% [markdown]
# 2. Find the length of the string "Hello World"

# %%
text = " Hello word "
print(len(text))
# Out:
# 12

# %% [markdown]
# 3. Ask the user to enter a number as a string and convert it to an integer. Add 10 and print the result.

# %%
num_str = input("enter a number:")
print(num_str)
num_int = int(num_str)
result = num_int + 10
print(f"The result is:{result}")
# Out:
# enter a number: 45
# 45
# The result is:55

# %% [markdown]
# 4. Extract the word "fun" from the string "Python is fun" using slicing.

# %%
s = "python is fun"
fun=s[-3:]
print(fun)
# Out:
# fun

# %% [markdown]
# 5. Count how many words are in the string "Machine Learning is powerful" using split() and len()

# %%
text = "  Machine Learning is powerful  "
print(len(text.split()))
# Out:
# 4

# %%
text = "  Machine Learning is powerful  "
len(text)
# Out:
# 32

# %% [markdown]
# 6. Remove leading and trailing spaces from the string "  Welcome  "

# %%
text = " welcome "
print(text.strip())
# Out:
# welcome

# %% [markdown]
# 7. Check if the word "Data" is present in the string "Big Data Analytics"

# %%
msg = "Big Data Analytic"
print("Data" in msg)
# Out:
# True

# %% [markdown]
# 8. Join the list ["AI", "ML", "DL"] into a single string with hyphens (-)

# %%
name_list=["AL","ML","DL"]
result= "-".join(name_list)
print(result)
# Out:
# AL-ML-DL

# %% [markdown]
# 9. Replace the word "difficult" with "easy" in "Python is difficult"

# %%
s = "python is difficult"
s =s.replace("difficult","easy")
print(s)
# Out:
# python is easy

# %% [markdown]
# 10. Find the maximum number from the list [10, 45, 3, 99, 23] using a built-in function

# %%
num = (10,45,3,99,23)
print(max(num))
# Out:
# 99
